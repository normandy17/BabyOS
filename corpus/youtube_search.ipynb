# %%
CURATED_VIDEO_SOURCES: dict[str, dict] = {
    "nhs_start_for_life": {
        "name": "NHS Start for Life",
        "section": "both",
        "youtube_channel": "@NHSUK",
        "country": "UK",
        "official": True,
    },

    "tommys": {
        "name": "Tommy's",
        "section": "pregnancy",
        "youtube_channel": "@Tommys-pregnancy-baby-charity",
        "country": "UK",
        "official": True,
    },

    "unicef_parenting": {
        "name": "UNICEF Parenting",
        "section": "postpartum",
        "youtube_channel": "@UNICEF",
        "country": "Global",
        "official": True,
    },

    "acog": {
        "name": "ACOG",
        "section": "pregnancy",
        "youtube_channel": "@EveryStageHealth",
        "country": "USA",
        "official": True,
    },

    "march_of_dimes": {
        "name": "March of Dimes",
        "section": "both",
        "youtube_channel": "@marchofdimes",
        "country": "USA",
        "official": True,
    },

    "mayo_clinic": {
        "name": "Mayo Clinic",
        "section": "both",
        "youtube_channel": "@MayoClinic",
        "country": "USA",
        "official": True,
    },

    "cleveland_clinic": {
        "name": "Cleveland Clinic",
        "section": "both",
        "youtube_channel": "@ClevelandClinic",
        "country": "USA",
        "official": True,
    },

    "stanford_childrens": {
        "name": "Stanford Children's Health",
        "section": "postpartum",
        "youtube_channel": "@clevelandclinic",
        "country": "USA",
        "official": True,
    },

    "johns_hopkins_medicine": {
        "name": "Johns Hopkins Medicine",
        "section": "both",
        "youtube_channel": "@JohnsHopkinsMedicine",
        "country": "USA",
        "official": True,
    },

    "american_pregnancy_association": {
        "name": "American Pregnancy Association",
        "section": "pregnancy",
        "youtube_channel": "@americanpregnancyassociation",
        "country": "USA",
        "official": True,
    },
}

YOUTUBE_SEARCH_TEMPLATES: dict[str, list[str]] = {
    "labour": [
        "signs of labour", "what to expect during labour", "labour pain relief",
        "early labour symptoms", "birth plan preparation",
        "when to go to hospital labour", "induced labour explained",
        "labour stages explained", "natural birth techniques"
    ],

    "pregnancy": [
        "pregnancy week by week", "first trimester symptoms", "second trimester questions",
        "third trimester tips", "antenatal appointments explained",
        "early pregnancy symptoms", "pregnancy nutrition guide",
        "exercise during pregnancy safe", "pregnancy warning signs"
    ],

    "postpartum": [
        "postnatal depression", "postpartum recovery", "postpartum care for new moms",
        "fourth trimester explained", "postpartum bleeding what to expect",
        "postpartum emotions", "postpartum body changes", "postpartum recovery timeline"
    ],

    "baby_care": [
        "newborn care basics", "breastfeeding tips", "skin to skin contact",
        "responsive feeding", "newborn milestones",
        "baby bath newborn how to", "umbilical cord care", "diaper changing newborn",
        "baby sleep routine newborn"
    ],

    "dad_partner": [
        "how to support your partner in labour", "new dad survival guide", "paternity leave tips",
        "partner support in pregnancy", "supporting breastfeeding partner",
        "what dads should know newborn", "how to help postpartum partner"
    ],

    "nutrition": [
        "pregnancy diet what to eat", "foods to avoid during pregnancy",
        "prenatal vitamins explained", "healthy pregnancy snacks",
        "iron rich foods pregnancy", "gestational diabetes diet"
    ],

    "mental_health": [
        "perinatal mental health", "postpartum depression signs",
        "anxiety during pregnancy", "baby blues vs depression",
        "coping strategies new parents", "when to seek help postpartum"
    ],

    "safe_sleep": [
        "safe sleep for newborns", "SIDS prevention tips",
        "baby sleep safety guidelines", "crib safety newborn",
        "how to put baby to sleep safely"
    ],

    "breastfeeding": [
        "how to breastfeed newborn", "breastfeeding positions",
        "latching techniques breastfeeding", "breastfeeding problems solutions",
        "pumping breast milk guide", "combining breastfeeding and formula"
    ],

    "newborn_development": [
        "newborn milestones month 1", "baby development first 3 months",
        "how babies develop vision hearing", "tummy time benefits",
        "what to expect newborn development"
    ],

    "vaccination": [
        "baby vaccination schedule explained", "newborn vaccines what to expect",
        "vaccines side effects babies", "why vaccines are important newborn"
    ]
}

# %%
import re

PERIOD_PATTERNS: dict[str, list[str]] = {
    # Pregnancy months
    "pregnancy_m1": [r"\bweek [1-4]\b", r"\bmonth 1\b", r"\bimplantat\b", r"\bembry\b"],
    "pregnancy_m2": [r"\bweek [5-8]\b", r"\bmonth 2\b", r"\bhcg\b"],
    "pregnancy_m3": [r"\bweek [9-9]\b", r"\bweek 1[0-2]\b", r"\bmonth 3\b", r"\bfirst trimester\b", r"\b12.week scan\b"],
    "pregnancy_m4": [r"\bweek 1[3-6]\b", r"\bmonth 4\b", r"\bsecond trimester\b"],
    "pregnancy_m5": [r"\bweek 1[7-9]\b", r"\bweek 20\b", r"\bmonth 5\b", r"\banatomy scan\b", r"\b20.week\b"],
    "pregnancy_m6": [r"\bweek 2[1-4]\b", r"\bmonth 6\b", r"\bglucose\b", r"\bgtt\b"],
    "pregnancy_m7": [r"\bweek 2[5-8]\b", r"\bmonth 7\b", r"\bthird trimester\b"],
    "pregnancy_m8": [r"\bweek 2[9-9]\b", r"\bweek 3[0-2]\b", r"\bmonth 8\b"],
    "pregnancy_m9": [r"\bweek 3[3-9]\b", r"\bweek 40\b", r"\bmonth 9\b", r"\bterm\b", r"\blabou?r\b", r"\bdue date\b"],
    # Postpartum months
    "postpartum_m0": [r"\bnewborn\b", r"\bday [1-9]\b", r"\bfirst week\b", r"\bapgar\b", r"\bu1\b", r"\bu2\b"],
    "postpartum_m1": [r"\b[23456] weeks? (old|postpartum|after)\b", r"\bwochenbett\b", r"\b6.week check\b"],
    "postpartum_m2": [r"\b2 months?\b", r"\b8 weeks?\b", r"\bu3\b"],
    "postpartum_m3": [r"\b3 months?\b", r"\b12 weeks?\b", r"\bu4\b"],
    "postpartum_m4": [r"\b4 months?\b", r"\bsleep regression\b"],
    "postpartum_m6": [r"\b6 months?\b", r"\bweaning\b", r"\bfirst food\b", r"\bsolids\b", r"\bu5\b"],
    "postpartum_m9": [r"\b9 months?\b", r"\bcrawl\b", r"\bpull.to.stand\b"],
    "postpartum_m12": [r"\b12 months?\b", r"\bone year\b", r"\bfirst birthday\b", r"\bfirst step\b", r"\bu6\b"],
    "postpartum_m18": [r"\b18 months?\b", r"\btoddler\b", r"\btantrum\b"],
    "postpartum_m24": [r"\b24 months?\b", r"\b2 years?\b", r"\bfirst step\b", r"\bu7\b"],
}

_COMPILED_PERIODS = {p: [re.compile(r, re.IGNORECASE) for r in pats] for p, pats in PERIOD_PATTERNS.items()}

def detect_period(text: str) -> str:
    """Return the best matching period for a chunk. Explicit week/pp_weeks take priority."""
    q      = text[:1000]
    scores = {p: sum(1 for r in pats if r.search(q)) for p, pats in _COMPILED_PERIODS.items()}
    scores = {p: s for p, s in scores.items() if s > 0}
    return max(scores, key=scores.__getitem__) if scores else "all"

# %%
from googleapiclient.discovery import build
from collections import defaultdict

def build_curated_video_collection(
    api_key: str = "AIzaSyDz28d6-wEjEWo2PAn3mscbw9jL4xvh9A4",
    sources: dict = CURATED_VIDEO_SOURCES,
    search_templates: dict = YOUTUBE_SEARCH_TEMPLATES,
    max_results_per_query: int = 5
):
    youtube = build("youtube", "v3", developerKey=api_key)
    final = defaultdict(lambda: {
        "name": "",
        "section": "",
        "videos": {}
    })

    for source_key, source in sources.items():
        channel = source["youtube_channel"]

        final[source_key]["name"] = source["name"]
        final[source_key]["section"] = source["section"]

        # iterate topics
        for topic, queries in search_templates.items():

            for query in queries:

                search_response = youtube.search().list(
                    q=query,
                    part="snippet",
                    type="video",
                    maxResults=max_results_per_query,
                    channelId=channel,
                    safeSearch="strict"
                ).execute()

                for item in search_response.get("items", []):

                    video_id = item["id"]["videoId"]
                    title = item["snippet"]["title"]

                    # avoid duplicates
                    if video_id in final[source_key]["videos"]:
                        continue

                    period = infer_period(topic)

                    final[source_key]["videos"][video_id] = {
                        "topic": topic,
                        "period": period,
                        "title": title
                    }

    return dict(final)

# %%
build_curated_video_collection()
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 build_curated_video_collection()
#
# Cell In[9], line 35, in build_curated_video_collection(api_key, sources, search_templates, max_results_per_query)
#      24 for topic, queries in search_templates.items():
#      26     for query in queries:
#      28         search_response = youtube.search().list(
#      29             q=query,
#      30             part="snippet",
#      31             type="video",
#      32             maxResults=max_results_per_query,
#      33             channelId=channel,
#      34             safeSearch="strict"
# ---> 35         ).execute()
#      37         for item in search_response.get("items", []):
#      39             video_id = item["id"]["videoId"]
#
# ...
